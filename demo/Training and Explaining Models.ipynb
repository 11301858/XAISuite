# %%
from xaisuite import*
from sklearn import datasets
import warnings
warnings.filterwarnings("ignore")

# %%
models = ["SVR", "RandomForestRegressor", "DecisionTreeClassifier", "RandomForestClassifier", "LogisticRegression"]
explainers = ["lime", "shap"]

# %%
train_and_explainModel(models[0], load_data_CSV('energy_efficiency_data.csv', 'Heating_Load', 'Cooling_Load'), explainers)
train_and_explainModel(models[2], load_data_sklearn(datasets.load_diabetes(), 'target'), explainers)
train_and_explainModel(models[1], load_data_sklearn(datasets.load_iris(), 'target'), explainers)



train_and_explainModel(models[4], load_data_sklearn(datasets.fetch_olivetti_faces(), 'target'), explainers, scale = False, verbose = True)
train_and_explainModel(models[3], load_data_sklearn(datasets.load_digits(), 'target'), explainers, scale = False, verbose = True)

# %% [markdown]
# We hope you found this demo useful!
